# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('veri.csv',encoding='unicode_escape') #verisetini yükledik

# %%
df.head()
# Out:
#      CITY'              'DATE'   SO2    NO2      CO     O3   PM10
# 0  'ADANA'  '44866.0006481481'  3.04  11.14  438.95  64.05  47.99
# 1  'ADANA'  '44867.0006481481'  1.93   9.10  383.02  58.09  33.61
# 2  'ADANA'  '44868.0006481481'  2.36   7.92  452.69  66.01  29.79
# 3  'ADANA'  '44869.0006481481'  4.41   8.27  488.94  68.00  27.41
# 4  'ADANA'  '44870.0006481481'  3.87   8.31  525.01  62.61  30.88

# %%
df.shape#veri setindeki satır ve sütünlar
# Out:
# (499, 7)

# %%
df.isnull().sum()#boş değer var mi kontrolü
# Out:
# CITY'     0
# 'DATE'    0
# SO2       0
# NO2       0
# CO        0
# O3        0
# PM10      0
# dtype: int64

# %%
df.describe()
# Out:
#               SO2         NO2           CO          O3        PM10
# count  499.000000  499.000000   499.000000  499.000000  499.000000
# mean    14.846473   47.818589  1074.389644   25.761892   58.068628
# std     12.269851   33.426670   659.961862   13.929503   39.265260
# min      0.360000    2.080000   165.890000    5.060000    1.170000
# 25%      6.860000   27.635000   588.635000   16.120000   32.050000
# 50%     10.370000   40.000000   913.790000   22.930000   48.940000
# 75%     19.705000   58.455833  1419.460000   32.890000   70.660000
# max     98.560000  200.500000  4018.140000  109.340000  223.540000

# %%
df.nunique() #her satırdakı benzersiz değerin kaç tane olduğunu gösterir
# Out:
# CITY'      50
# 'DATE'     10
# SO2       456
# NO2       479
# CO        488
# O3        455
# PM10      474
# dtype: int64

# %%
df.columns
# Out:
# Index(['CITY'', ''DATE'', 'SO2', 'NO2', 'CO', 'O3', 'PM10'], dtype='object')

# %%
sns.pairplot(data=df)
plt.show()
